# %% [markdown]
# # Simulated Data 2M

# %%
# importing pandas and numpy libraries 
import numpy as np 
import pandas as pd

# %%
data_file = 'Resources/y_describe_best_actual.csv'
data_df = pd.read_csv(data_file)
data_df
# Out:
#    Y_Htr Outlet Temp  Y_Top Tower Temp  Y_Reflux Temp  Y_Pump Around Temp  \
# 0         731.022033        258.046943     150.002569          182.446049
# 1           2.320612          4.300249       0.129397            2.818279
#
#    Y_127 to Storage Temp  Y_140 to Storage Temp  Y_152 to Storage Temp  \
# 0             209.503398             227.032520             200.028309
# 1              16.247064              15.734074               1.571367
#
#    Y_160 to Storage Temp  Y_VTB to Storage Temp  Y_127 Strip Lvl Pcnt  \
# 0             193.373220             235.057740             64.815675
# 1              14.918037               5.221583              1.565423
#
#    Y_140 Strip Lvl Pcnt  Y_152 Strip Lvl Pcnt  Y_160 Strip Lvl Pcnt  \
# 0             49.999854             50.005252             63.223805
# 1              0.033646              0.133327              6.530495
#
#    Y_Vacuum Charge Flow   Y_REFLUX  Y_PUMP AROUND  Y_Wash Flow  \
# ...

# %%
print(data_df.loc[0,"Y_Htr Outlet Temp"])
print(data_df.loc[1,"Y_Htr Outlet Temp"])
# Out:
# 731.0220325203252
# 2.320612128384772

# %%
k = 2000000 # number of simulations

s = np.random.uniform(data_df.loc[0,"Y_Htr Outlet Temp"] - data_df.loc[1,"Y_Htr Outlet Temp"], data_df.loc[0,"Y_Htr Outlet Temp"] + data_df.loc[1,"Y_Htr Outlet Temp"], k)
sim_2M_df = pd.DataFrame(s, columns = ['Y_Htr Outlet Temp']) 
  
# displaying random integers in data frame 
sim_2M_df.head()
# Out:
#    Y_Htr Outlet Temp
# 0         731.514221
# 1         728.888879
# 2         730.924492
# 3         729.372073
# 4         731.300118

# %%
sim_2M_df['Y_Top Tower Temp'] = np.random.uniform(data_df.loc[0, 'Y_Top Tower Temp'] - data_df.loc[1, 'Y_Top Tower Temp'], data_df.loc[0, 'Y_Top Tower Temp'] + data_df.loc[1, 'Y_Top Tower Temp'], k)
sim_2M_df['Y_Reflux Temp'] = np.random.uniform(data_df.loc[0, 'Y_Reflux Temp'] - data_df.loc[1, 'Y_Reflux Temp'], data_df.loc[0, 'Y_Reflux Temp'] + data_df.loc[1,'Y_Reflux Temp'], k)
sim_2M_df['Y_Pump Around Temp'] = np.random.uniform(data_df.loc[0, 'Y_Pump Around Temp'] - data_df.loc[1, 'Y_Pump Around Temp'], data_df.loc[0, 'Y_Pump Around Temp'] + data_df.loc[1, 'Y_Pump Around Temp'], k)
sim_2M_df['Y_127 to Storage Temp'] = np.random.uniform(data_df.loc[0, 'Y_127 to Storage Temp'] - data_df.loc[1, 'Y_127 to Storage Temp'], data_df.loc[0, 'Y_127 to Storage Temp'] + data_df.loc[1, 'Y_127 to Storage Temp'], k)
sim_2M_df['Y_140 to Storage Temp'] = np.random.uniform(data_df.loc[0, 'Y_140 to Storage Temp'] - data_df.loc[1, 'Y_140 to Storage Temp'], data_df.loc[0, 'Y_140 to Storage Temp'] + data_df.loc[1, 'Y_140 to Storage Temp'], k)
sim_2M_df['Y_152 to Storage Temp'] = np.random.uniform(data_df.loc[0, 'Y_152 to Storage Temp'] - data_df.loc[1, 'Y_152 to Storage Temp'], data_df.loc[0, 'Y_152 to Storage Temp'] + data_df.loc[1, 'Y_152 to Storage Temp'], k)
sim_2M_df['Y_160 to Storage Temp'] = np.random.uniform(data_df.loc[0, 'Y_160 to Storage Temp'] - data_df.loc[1, 'Y_160 to Storage Temp'], data_df.loc[0, 'Y_160 to Storage Temp'] + data_df.loc[1, 'Y_160 to Storage Temp'], k)
sim_2M_df['Y_VTB to Storage Temp'] = np.random.uniform(data_df.loc[0, 'Y_VTB to Storage Temp'] - data_df.loc[1, 'Y_VTB to Storage Temp'], data_df.loc[0, 'Y_VTB to Storage Temp'] + data_df.loc[1, 'Y_VTB to Storage Temp'], k)
sim_2M_df['Y_127 Strip Lvl Pcnt'] = np.random.uniform(data_df.loc[0, 'Y_127 Strip Lvl Pcnt'] - data_df.loc[1, 'Y_127 Strip Lvl Pcnt'], data_df.loc[0, 'Y_127 Strip Lvl Pcnt'] + data_df.loc[1, 'Y_127 Strip Lvl Pcnt'], k)
sim_2M_df['Y_140 Strip Lvl Pcnt'] = np.random.uniform(data_df.loc[0, 'Y_140 Strip Lvl Pcnt'] - data_df.loc[1, 'Y_140 Strip Lvl Pcnt'], data_df.loc[0, 'Y_140 Strip Lvl Pcnt'] + data_df.loc[1, 'Y_140 Strip Lvl Pcnt'], k)
sim_2M_df['Y_152 Strip Lvl Pcnt'] = np.random.uniform(data_df.loc[0, 'Y_152 Strip Lvl Pcnt'] - data_df.loc[1, 'Y_152 Strip Lvl Pcnt'], data_df.loc[0, 'Y_152 Strip Lvl Pcnt'] + data_df.loc[1, 'Y_152 Strip Lvl Pcnt'], k)
sim_2M_df['Y_160 Strip Lvl Pcnt'] = np.random.uniform(data_df.loc[0, 'Y_160 Strip Lvl Pcnt'] - data_df.loc[1, 'Y_160 Strip Lvl Pcnt'], data_df.loc[0, 'Y_160 Strip Lvl Pcnt'] + data_df.loc[1, 'Y_160 Strip Lvl Pcnt'], k)
sim_2M_df['Y_Vacuum Charge Flow'] = np.random.uniform(data_df.loc[0, 'Y_Vacuum Charge Flow'] - data_df.loc[1, 'Y_Vacuum Charge Flow'], data_df.loc[0, 'Y_Vacuum Charge Flow'] + data_df.loc[1, 'Y_Vacuum Charge Flow'], k)
sim_2M_df['Y_REFLUX'] = np.random.uniform(data_df.loc[0, 'Y_REFLUX'] - data_df.loc[1, 'Y_REFLUX'], data_df.loc[0, 'Y_REFLUX'] + data_df.loc[1, 'Y_REFLUX'], k)
sim_2M_df['Y_PUMP AROUND'] =  np.random.uniform(data_df.loc[0, 'Y_PUMP AROUND'] - data_df.loc[1, 'Y_PUMP AROUND'], data_df.loc[0, 'Y_PUMP AROUND'] + data_df.loc[1, 'Y_PUMP AROUND'], k)
sim_2M_df['Y_Wash Flow'] = np.random.uniform(data_df.loc[0, 'Y_Wash Flow'] - data_df.loc[1, 'Y_Wash Flow'], data_df.loc[0, 'Y_Wash Flow'] + data_df.loc[1, 'Y_Wash Flow'], k)
sim_2M_df['Y_127 to Storage Flow'] = np.random.uniform(data_df.loc[0, 'Y_127 to Storage Flow'] - data_df.loc[1, 'Y_127 to Storage Flow'], data_df.loc[0, 'Y_127 to Storage Flow'] + data_df.loc[1, 'Y_127 to Storage Flow'], k)
sim_2M_df['Y_140 to Storage Flow'] = np.random.uniform(data_df.loc[0, 'Y_140 to Storage Flow'] - data_df.loc[1, 'Y_140 to Storage Flow'], data_df.loc[0, 'Y_140 to Storage Flow'] + data_df.loc[1, 'Y_140 to Storage Flow'], k)
sim_2M_df['Y_152 to Storage Flow'] = np.random.uniform(data_df.loc[0, 'Y_152 to Storage Flow'] - data_df.loc[1, 'Y_152 to Storage Flow'], data_df.loc[0, 'Y_152 to Storage Flow'] + data_df.loc[1, 'Y_152 to Storage Flow'], k)
sim_2M_df['Y_160 to Storage Flow'] = np.random.uniform(data_df.loc[0, 'Y_160 to Storage Flow'] - data_df.loc[1, 'Y_160 to Storage Flow'], data_df.loc[0, 'Y_160 to Storage Flow'] + data_df.loc[1, 'Y_160 to Storage Flow'], k)
sim_2M_df['Y_8TH TUBE'] = np.random.uniform(data_df.loc[0, 'Y_8TH TUBE'] - data_df.loc[1, 'Y_8TH TUBE'], data_df.loc[0, 'Y_8TH TUBE'] + data_df.loc[1, 'Y_8TH TUBE'], k)
sim_2M_df['Y_Stripping Steam Tower Flow'] = np.random.uniform(data_df.loc[0, 'Y_Stripping Steam Tower Flow'] - data_df.loc[1, 'Y_Stripping Steam Tower Flow'], data_df.loc[0, 'Y_Stripping Steam Tower Flow'] + data_df.loc[1, 'Y_Stripping Steam Tower Flow'], k)
sim_2M_df['Y_127 Stripping Stream Flow'] = np.random.uniform(data_df.loc[0, 'Y_127 Stripping Stream Flow'] - data_df.loc[1, 'Y_127 Stripping Stream Flow'], data_df.loc[0, 'Y_127 Stripping Stream Flow'] + data_df.loc[1, 'Y_127 Stripping Stream Flow'], k)
sim_2M_df['Y_140 Stripping Stream Flow'] = np.random.uniform(data_df.loc[0, 'Y_140 Stripping Stream Flow'] - data_df.loc[1, 'Y_140 Stripping Stream Flow'], data_df.loc[0, 'Y_140 Stripping Stream Flow'] + data_df.loc[1, 'Y_140 Stripping Stream Flow'], k)
sim_2M_df['Y_152 Stripping Stream Flow'] = np.random.uniform(data_df.loc[0, 'Y_152 Stripping Stream Flow'] - data_df.loc[1, 'Y_152 Stripping Stream Flow'], data_df.loc[0, 'Y_152 Stripping Stream Flow'] + data_df.loc[1, 'Y_152 Stripping Stream Flow'], k)
sim_2M_df['Y_160 Stripping Stream Flow'] = np.random.uniform(data_df.loc[0, 'Y_160 Stripping Stream Flow'] - data_df.loc[1, 'Y_160 Stripping Stream Flow'], data_df.loc[0, 'Y_160 Stripping Stream Flow'] + data_df.loc[1, 'Y_160 Stripping Stream Flow'], k)

# %%
pd.set_option('display.max_columns', None)
sim_2M_df
# Out:
#          Y_Htr Outlet Temp  Y_Top Tower Temp  Y_Reflux Temp  \
# 0               731.514221        258.584629     149.929087
# 1               728.888879        261.376951     149.894580
# 2               730.924492        261.372349     150.053318
# 3               729.372073        254.641603     149.924992
# 4               731.300118        257.212767     150.058603
# ...                    ...               ...            ...
# 1999995         731.870022        256.502612     149.925811
# 1999996         732.433903        257.606696     150.054552
# 1999997         731.452882        257.378493     150.004947
# 1999998         729.458426        259.757714     149.985533
# 1999999         731.182335        256.873735     150.110297
#
#          Y_Pump Around Temp  Y_127 to Storage Temp  Y_140 to Storage Temp  \
# 0                183.457016             221.646996             228.551054
# 1                180.277731             211.013558             220.922579
# ...

# %%
sim_2M_df.to_csv('Resources/simulated_2M_data.csv',index=False)

# %% [markdown]
# # Simulated Data 1M

# %%
data_file = 'Resources/sim_2M_describe.csv'
data_df = pd.read_csv(data_file)
data_df
# Out:
#    Y_Htr Outlet Temp  Y_Top Tower Temp  Y_Reflux Temp  Y_Pump Around Temp  \
# 0         730.970885        258.092781     150.001829          182.439210
# 1           1.351149          2.469473       0.074578            1.626518
#
#    Y_127 to Storage Temp  Y_140 to Storage Temp  Y_152 to Storage Temp  \
# 0             208.749078             225.729202             200.029066
# 1               9.219019               8.719633               0.906074
#
#    Y_160 to Storage Temp  Y_VTB to Storage Temp  Y_127 Strip Lvl Pcnt  \
# 0             193.110176             234.318502             64.831828
# 1               8.754074               2.891341              0.902829
#
#    Y_140 Strip Lvl Pcnt  Y_152 Strip Lvl Pcnt  Y_160 Strip Lvl Pcnt  \
# 0             49.999867             50.005915             63.209606
# 1              0.019424              0.076906              3.771876
#
#    Y_Vacuum Charge Flow   Y_REFLUX  Y_PUMP AROUND  Y_Wash Flow  \
# ...

# %%
k = 1000000 # number of simulations

s = np.random.uniform(data_df.loc[0,"Y_Htr Outlet Temp"] - data_df.loc[1,"Y_Htr Outlet Temp"], data_df.loc[0,"Y_Htr Outlet Temp"] + data_df.loc[1,"Y_Htr Outlet Temp"], k)
sim_1M_df = pd.DataFrame(s, columns = ['Y_Htr Outlet Temp']) 
  
# displaying random integers in data frame 
sim_1M_df.head()
# Out:
#    Y_Htr Outlet Temp
# 0         730.241741
# 1         731.026888
# 2         731.444352
# 3         731.736689
# 4         729.776002

# %%
sim_1M_df['Y_Top Tower Temp'] = np.random.uniform(data_df.loc[0, 'Y_Top Tower Temp'] - data_df.loc[1, 'Y_Top Tower Temp'], data_df.loc[0, 'Y_Top Tower Temp'] + data_df.loc[1, 'Y_Top Tower Temp'], k)
sim_1M_df['Y_Reflux Temp'] = np.random.uniform(data_df.loc[0, 'Y_Reflux Temp'] - data_df.loc[1, 'Y_Reflux Temp'], data_df.loc[0, 'Y_Reflux Temp'] + data_df.loc[1,'Y_Reflux Temp'], k)
sim_1M_df['Y_Pump Around Temp'] = np.random.uniform(data_df.loc[0, 'Y_Pump Around Temp'] - data_df.loc[1, 'Y_Pump Around Temp'], data_df.loc[0, 'Y_Pump Around Temp'] + data_df.loc[1, 'Y_Pump Around Temp'], k)
sim_1M_df['Y_127 to Storage Temp'] = np.random.uniform(data_df.loc[0, 'Y_127 to Storage Temp'] - data_df.loc[1, 'Y_127 to Storage Temp'], data_df.loc[0, 'Y_127 to Storage Temp'] + data_df.loc[1, 'Y_127 to Storage Temp'], k)
sim_1M_df['Y_140 to Storage Temp'] = np.random.uniform(data_df.loc[0, 'Y_140 to Storage Temp'] - data_df.loc[1, 'Y_140 to Storage Temp'], data_df.loc[0, 'Y_140 to Storage Temp'] + data_df.loc[1, 'Y_140 to Storage Temp'], k)
sim_1M_df['Y_152 to Storage Temp'] = np.random.uniform(data_df.loc[0, 'Y_152 to Storage Temp'] - data_df.loc[1, 'Y_152 to Storage Temp'], data_df.loc[0, 'Y_152 to Storage Temp'] + data_df.loc[1, 'Y_152 to Storage Temp'], k)
sim_1M_df['Y_160 to Storage Temp'] = np.random.uniform(data_df.loc[0, 'Y_160 to Storage Temp'] - data_df.loc[1, 'Y_160 to Storage Temp'], data_df.loc[0, 'Y_160 to Storage Temp'] + data_df.loc[1, 'Y_160 to Storage Temp'], k)
sim_1M_df['Y_VTB to Storage Temp'] = np.random.uniform(data_df.loc[0, 'Y_VTB to Storage Temp'] - data_df.loc[1, 'Y_VTB to Storage Temp'], data_df.loc[0, 'Y_VTB to Storage Temp'] + data_df.loc[1, 'Y_VTB to Storage Temp'], k)
sim_1M_df['Y_127 Strip Lvl Pcnt'] = np.random.uniform(data_df.loc[0, 'Y_127 Strip Lvl Pcnt'] - data_df.loc[1, 'Y_127 Strip Lvl Pcnt'], data_df.loc[0, 'Y_127 Strip Lvl Pcnt'] + data_df.loc[1, 'Y_127 Strip Lvl Pcnt'], k)
sim_1M_df['Y_140 Strip Lvl Pcnt'] = np.random.uniform(data_df.loc[0, 'Y_140 Strip Lvl Pcnt'] - data_df.loc[1, 'Y_140 Strip Lvl Pcnt'], data_df.loc[0, 'Y_140 Strip Lvl Pcnt'] + data_df.loc[1, 'Y_140 Strip Lvl Pcnt'], k)
sim_1M_df['Y_152 Strip Lvl Pcnt'] = np.random.uniform(data_df.loc[0, 'Y_152 Strip Lvl Pcnt'] - data_df.loc[1, 'Y_152 Strip Lvl Pcnt'], data_df.loc[0, 'Y_152 Strip Lvl Pcnt'] + data_df.loc[1, 'Y_152 Strip Lvl Pcnt'], k)
sim_1M_df['Y_160 Strip Lvl Pcnt'] = np.random.uniform(data_df.loc[0, 'Y_160 Strip Lvl Pcnt'] - data_df.loc[1, 'Y_160 Strip Lvl Pcnt'], data_df.loc[0, 'Y_160 Strip Lvl Pcnt'] + data_df.loc[1, 'Y_160 Strip Lvl Pcnt'], k)
sim_1M_df['Y_Vacuum Charge Flow'] = np.random.uniform(data_df.loc[0, 'Y_Vacuum Charge Flow'] - data_df.loc[1, 'Y_Vacuum Charge Flow'], data_df.loc[0, 'Y_Vacuum Charge Flow'] + data_df.loc[1, 'Y_Vacuum Charge Flow'], k)
sim_1M_df['Y_REFLUX'] = np.random.uniform(data_df.loc[0, 'Y_REFLUX'] - data_df.loc[1, 'Y_REFLUX'], data_df.loc[0, 'Y_REFLUX'] + data_df.loc[1, 'Y_REFLUX'], k)
sim_1M_df['Y_PUMP AROUND'] =  np.random.uniform(data_df.loc[0, 'Y_PUMP AROUND'] - data_df.loc[1, 'Y_PUMP AROUND'], data_df.loc[0, 'Y_PUMP AROUND'] + data_df.loc[1, 'Y_PUMP AROUND'], k)
sim_1M_df['Y_Wash Flow'] = np.random.uniform(data_df.loc[0, 'Y_Wash Flow'] - data_df.loc[1, 'Y_Wash Flow'], data_df.loc[0, 'Y_Wash Flow'] + data_df.loc[1, 'Y_Wash Flow'], k)
sim_1M_df['Y_127 to Storage Flow'] = np.random.uniform(data_df.loc[0, 'Y_127 to Storage Flow'] - data_df.loc[1, 'Y_127 to Storage Flow'], data_df.loc[0, 'Y_127 to Storage Flow'] + data_df.loc[1, 'Y_127 to Storage Flow'], k)
sim_1M_df['Y_140 to Storage Flow'] = np.random.uniform(data_df.loc[0, 'Y_140 to Storage Flow'] - data_df.loc[1, 'Y_140 to Storage Flow'], data_df.loc[0, 'Y_140 to Storage Flow'] + data_df.loc[1, 'Y_140 to Storage Flow'], k)
sim_1M_df['Y_152 to Storage Flow'] = np.random.uniform(data_df.loc[0, 'Y_152 to Storage Flow'] - data_df.loc[1, 'Y_152 to Storage Flow'], data_df.loc[0, 'Y_152 to Storage Flow'] + data_df.loc[1, 'Y_152 to Storage Flow'], k)
sim_1M_df['Y_160 to Storage Flow'] = np.random.uniform(data_df.loc[0, 'Y_160 to Storage Flow'] - data_df.loc[1, 'Y_160 to Storage Flow'], data_df.loc[0, 'Y_160 to Storage Flow'] + data_df.loc[1, 'Y_160 to Storage Flow'], k)
sim_1M_df['Y_8TH TUBE'] = np.random.uniform(data_df.loc[0, 'Y_8TH TUBE'] - data_df.loc[1, 'Y_8TH TUBE'], data_df.loc[0, 'Y_8TH TUBE'] + data_df.loc[1, 'Y_8TH TUBE'], k)
sim_1M_df['Y_Stripping Steam Tower Flow'] = np.random.uniform(data_df.loc[0, 'Y_Stripping Steam Tower Flow'] - data_df.loc[1, 'Y_Stripping Steam Tower Flow'], data_df.loc[0, 'Y_Stripping Steam Tower Flow'] + data_df.loc[1, 'Y_Stripping Steam Tower Flow'], k)
sim_1M_df['Y_127 Stripping Stream Flow'] = np.random.uniform(data_df.loc[0, 'Y_127 Stripping Stream Flow'] - data_df.loc[1, 'Y_127 Stripping Stream Flow'], data_df.loc[0, 'Y_127 Stripping Stream Flow'] + data_df.loc[1, 'Y_127 Stripping Stream Flow'], k)
sim_1M_df['Y_140 Stripping Stream Flow'] = np.random.uniform(data_df.loc[0, 'Y_140 Stripping Stream Flow'] - data_df.loc[1, 'Y_140 Stripping Stream Flow'], data_df.loc[0, 'Y_140 Stripping Stream Flow'] + data_df.loc[1, 'Y_140 Stripping Stream Flow'], k)
sim_1M_df['Y_152 Stripping Stream Flow'] = np.random.uniform(data_df.loc[0, 'Y_152 Stripping Stream Flow'] - data_df.loc[1, 'Y_152 Stripping Stream Flow'], data_df.loc[0, 'Y_152 Stripping Stream Flow'] + data_df.loc[1, 'Y_152 Stripping Stream Flow'], k)
sim_1M_df['Y_160 Stripping Stream Flow'] = np.random.uniform(data_df.loc[0, 'Y_160 Stripping Stream Flow'] - data_df.loc[1, 'Y_160 Stripping Stream Flow'], data_df.loc[0, 'Y_160 Stripping Stream Flow'] + data_df.loc[1, 'Y_160 Stripping Stream Flow'], k)

# %%
pd.set_option('display.max_columns', None)
sim_1M_df
# Out:
#         Y_Htr Outlet Temp  Y_Top Tower Temp  Y_Reflux Temp  \
# 0              730.241741        259.198879     149.986980
# 1              731.026888        256.777167     150.061208
# 2              731.444352        256.628392     149.970153
# 3              731.736689        257.884950     149.943407
# 4              729.776002        260.522243     149.965952
# ...                   ...               ...            ...
# 999995         729.797406        256.687632     150.051837
# 999996         730.617398        255.686236     150.008634
# 999997         731.492548        256.892153     149.953868
# 999998         732.195344        260.348856     149.998131
# 999999         731.663944        257.396057     150.022922
#
#         Y_Pump Around Temp  Y_127 to Storage Temp  Y_140 to Storage Temp  \
# 0               182.061596             205.031356             219.851320
# 1               183.671084             200.693251             222.208473
# ...

# %%
sim_1M_df.to_csv('Resources/simulated_1M_data.csv',index=False)

# %% [markdown]
# # Simulated Data 500K

# %%
data_file = 'Resources/sim_1M_describe.csv'
data_df = pd.read_csv(data_file)
data_df
# Out:
#    Y_Htr Outlet Temp  Y_Top Tower Temp  Y_Reflux Temp  Y_Pump Around Temp  \
# 0         730.903717        258.166315     150.001512          182.428306
# 1           0.804538          1.416426       0.043067            0.937797
#
#    Y_127 to Storage Temp  Y_140 to Storage Temp  Y_152 to Storage Temp  \
# 0             208.583544             224.407811             200.021107
# 1               5.273453               4.803886               0.521109
#
#    Y_160 to Storage Temp  Y_VTB to Storage Temp  Y_127 Strip Lvl Pcnt  \
# 0             193.233719             234.162062             64.837989
# 1               5.017061               1.619944              0.521598
#
#    Y_140 Strip Lvl Pcnt  Y_152 Strip Lvl Pcnt  Y_160 Strip Lvl Pcnt  \
# 0             49.999944             50.005370             63.217669
# 1              0.011185              0.044408              2.180534
#
#    Y_Vacuum Charge Flow   Y_REFLUX  Y_PUMP AROUND  Y_Wash Flow  \
# ...

# %%
print(data_df.loc[0,"Y_Htr Outlet Temp"])
print(data_df.loc[1,"Y_Htr Outlet Temp"])
# Out:
# 730.9037169261592
# 0.8045382675551361

# %%
k = 500000 # number of simulations

s = np.random.uniform(data_df.loc[0,"Y_Htr Outlet Temp"] - data_df.loc[1,"Y_Htr Outlet Temp"], data_df.loc[0,"Y_Htr Outlet Temp"] + data_df.loc[1,"Y_Htr Outlet Temp"], k)
sim_500K_df = pd.DataFrame(s, columns = ['Y_Htr Outlet Temp']) 
  
# displaying random integers in data frame 
sim_500K_df.head()
# Out:
#    Y_Htr Outlet Temp
# 0         731.305817
# 1         731.660376
# 2         730.192414
# 3         730.338525
# 4         730.993913

# %%
sim_500K_df['Y_Top Tower Temp'] = np.random.uniform(data_df.loc[0, 'Y_Top Tower Temp'] - data_df.loc[1, 'Y_Top Tower Temp'], data_df.loc[0, 'Y_Top Tower Temp'] + data_df.loc[1, 'Y_Top Tower Temp'], k)
sim_500K_df['Y_Reflux Temp'] = np.random.uniform(data_df.loc[0, 'Y_Reflux Temp'] - data_df.loc[1, 'Y_Reflux Temp'], data_df.loc[0, 'Y_Reflux Temp'] + data_df.loc[1,'Y_Reflux Temp'], k)
sim_500K_df['Y_Pump Around Temp'] = np.random.uniform(data_df.loc[0, 'Y_Pump Around Temp'] - data_df.loc[1, 'Y_Pump Around Temp'], data_df.loc[0, 'Y_Pump Around Temp'] + data_df.loc[1, 'Y_Pump Around Temp'], k)
sim_500K_df['Y_127 to Storage Temp'] = np.random.uniform(data_df.loc[0, 'Y_127 to Storage Temp'] - data_df.loc[1, 'Y_127 to Storage Temp'], data_df.loc[0, 'Y_127 to Storage Temp'] + data_df.loc[1, 'Y_127 to Storage Temp'], k)
sim_500K_df['Y_140 to Storage Temp'] = np.random.uniform(data_df.loc[0, 'Y_140 to Storage Temp'] - data_df.loc[1, 'Y_140 to Storage Temp'], data_df.loc[0, 'Y_140 to Storage Temp'] + data_df.loc[1, 'Y_140 to Storage Temp'], k)
sim_500K_df['Y_152 to Storage Temp'] = np.random.uniform(data_df.loc[0, 'Y_152 to Storage Temp'] - data_df.loc[1, 'Y_152 to Storage Temp'], data_df.loc[0, 'Y_152 to Storage Temp'] + data_df.loc[1, 'Y_152 to Storage Temp'], k)
sim_500K_df['Y_160 to Storage Temp'] = np.random.uniform(data_df.loc[0, 'Y_160 to Storage Temp'] - data_df.loc[1, 'Y_160 to Storage Temp'], data_df.loc[0, 'Y_160 to Storage Temp'] + data_df.loc[1, 'Y_160 to Storage Temp'], k)
sim_500K_df['Y_VTB to Storage Temp'] = np.random.uniform(data_df.loc[0, 'Y_VTB to Storage Temp'] - data_df.loc[1, 'Y_VTB to Storage Temp'], data_df.loc[0, 'Y_VTB to Storage Temp'] + data_df.loc[1, 'Y_VTB to Storage Temp'], k)
sim_500K_df['Y_127 Strip Lvl Pcnt'] = np.random.uniform(data_df.loc[0, 'Y_127 Strip Lvl Pcnt'] - data_df.loc[1, 'Y_127 Strip Lvl Pcnt'], data_df.loc[0, 'Y_127 Strip Lvl Pcnt'] + data_df.loc[1, 'Y_127 Strip Lvl Pcnt'], k)
sim_500K_df['Y_140 Strip Lvl Pcnt'] = np.random.uniform(data_df.loc[0, 'Y_140 Strip Lvl Pcnt'] - data_df.loc[1, 'Y_140 Strip Lvl Pcnt'], data_df.loc[0, 'Y_140 Strip Lvl Pcnt'] + data_df.loc[1, 'Y_140 Strip Lvl Pcnt'], k)
sim_500K_df['Y_152 Strip Lvl Pcnt'] = np.random.uniform(data_df.loc[0, 'Y_152 Strip Lvl Pcnt'] - data_df.loc[1, 'Y_152 Strip Lvl Pcnt'], data_df.loc[0, 'Y_152 Strip Lvl Pcnt'] + data_df.loc[1, 'Y_152 Strip Lvl Pcnt'], k)
sim_500K_df['Y_160 Strip Lvl Pcnt'] = np.random.uniform(data_df.loc[0, 'Y_160 Strip Lvl Pcnt'] - data_df.loc[1, 'Y_160 Strip Lvl Pcnt'], data_df.loc[0, 'Y_160 Strip Lvl Pcnt'] + data_df.loc[1, 'Y_160 Strip Lvl Pcnt'], k)
sim_500K_df['Y_Vacuum Charge Flow'] = np.random.uniform(data_df.loc[0, 'Y_Vacuum Charge Flow'] - data_df.loc[1, 'Y_Vacuum Charge Flow'], data_df.loc[0, 'Y_Vacuum Charge Flow'] + data_df.loc[1, 'Y_Vacuum Charge Flow'], k)
sim_500K_df['Y_REFLUX'] = np.random.uniform(data_df.loc[0, 'Y_REFLUX'] - data_df.loc[1, 'Y_REFLUX'], data_df.loc[0, 'Y_REFLUX'] + data_df.loc[1, 'Y_REFLUX'], k)
sim_500K_df['Y_PUMP AROUND'] =  np.random.uniform(data_df.loc[0, 'Y_PUMP AROUND'] - data_df.loc[1, 'Y_PUMP AROUND'], data_df.loc[0, 'Y_PUMP AROUND'] + data_df.loc[1, 'Y_PUMP AROUND'], k)
sim_500K_df['Y_Wash Flow'] = np.random.uniform(data_df.loc[0, 'Y_Wash Flow'] - data_df.loc[1, 'Y_Wash Flow'], data_df.loc[0, 'Y_Wash Flow'] + data_df.loc[1, 'Y_Wash Flow'], k)
sim_500K_df['Y_127 to Storage Flow'] = np.random.uniform(data_df.loc[0, 'Y_127 to Storage Flow'] - data_df.loc[1, 'Y_127 to Storage Flow'], data_df.loc[0, 'Y_127 to Storage Flow'] + data_df.loc[1, 'Y_127 to Storage Flow'], k)
sim_500K_df['Y_140 to Storage Flow'] = np.random.uniform(data_df.loc[0, 'Y_140 to Storage Flow'] - data_df.loc[1, 'Y_140 to Storage Flow'], data_df.loc[0, 'Y_140 to Storage Flow'] + data_df.loc[1, 'Y_140 to Storage Flow'], k)
sim_500K_df['Y_152 to Storage Flow'] = np.random.uniform(data_df.loc[0, 'Y_152 to Storage Flow'] - data_df.loc[1, 'Y_152 to Storage Flow'], data_df.loc[0, 'Y_152 to Storage Flow'] + data_df.loc[1, 'Y_152 to Storage Flow'], k)
sim_500K_df['Y_160 to Storage Flow'] = np.random.uniform(data_df.loc[0, 'Y_160 to Storage Flow'] - data_df.loc[1, 'Y_160 to Storage Flow'], data_df.loc[0, 'Y_160 to Storage Flow'] + data_df.loc[1, 'Y_160 to Storage Flow'], k)
sim_500K_df['Y_8TH TUBE'] = np.random.uniform(data_df.loc[0, 'Y_8TH TUBE'] - data_df.loc[1, 'Y_8TH TUBE'], data_df.loc[0, 'Y_8TH TUBE'] + data_df.loc[1, 'Y_8TH TUBE'], k)
sim_500K_df['Y_Stripping Steam Tower Flow'] = np.random.uniform(data_df.loc[0, 'Y_Stripping Steam Tower Flow'] - data_df.loc[1, 'Y_Stripping Steam Tower Flow'], data_df.loc[0, 'Y_Stripping Steam Tower Flow'] + data_df.loc[1, 'Y_Stripping Steam Tower Flow'], k)
sim_500K_df['Y_127 Stripping Stream Flow'] = np.random.uniform(data_df.loc[0, 'Y_127 Stripping Stream Flow'] - data_df.loc[1, 'Y_127 Stripping Stream Flow'], data_df.loc[0, 'Y_127 Stripping Stream Flow'] + data_df.loc[1, 'Y_127 Stripping Stream Flow'], k)
sim_500K_df['Y_140 Stripping Stream Flow'] = np.random.uniform(data_df.loc[0, 'Y_140 Stripping Stream Flow'] - data_df.loc[1, 'Y_140 Stripping Stream Flow'], data_df.loc[0, 'Y_140 Stripping Stream Flow'] + data_df.loc[1, 'Y_140 Stripping Stream Flow'], k)
sim_500K_df['Y_152 Stripping Stream Flow'] = np.random.uniform(data_df.loc[0, 'Y_152 Stripping Stream Flow'] - data_df.loc[1, 'Y_152 Stripping Stream Flow'], data_df.loc[0, 'Y_152 Stripping Stream Flow'] + data_df.loc[1, 'Y_152 Stripping Stream Flow'], k)
sim_500K_df['Y_160 Stripping Stream Flow'] = np.random.uniform(data_df.loc[0, 'Y_160 Stripping Stream Flow'] - data_df.loc[1, 'Y_160 Stripping Stream Flow'], data_df.loc[0, 'Y_160 Stripping Stream Flow'] + data_df.loc[1, 'Y_160 Stripping Stream Flow'], k)

# %%
sim_500K_df
# Out:
#         Y_Htr Outlet Temp  Y_Top Tower Temp  Y_Reflux Temp  \
# 0              731.305817        258.202427     150.023490
# 1              731.660376        257.132116     149.964977
# 2              730.192414        257.152650     150.043623
# 3              730.338525        258.206372     149.998303
# 4              730.993913        257.295486     149.988567
# ...                   ...               ...            ...
# 499995         731.294422        259.158304     150.009900
# 499996         730.977138        257.818298     150.039363
# 499997         730.272269        259.258775     150.027299
# 499998         730.830216        257.393830     150.030407
# 499999         730.321071        257.254932     150.041091
#
#         Y_Pump Around Temp  Y_127 to Storage Temp  Y_140 to Storage Temp  \
# 0               181.631243             207.874028             228.172561
# 1               181.890981             205.105972             226.702764
# ...

# %%
sim_500K_df.to_csv('Resources/simulated_500K_data.csv',index=False)

# %% [markdown]
# # Simulated Data 250K

# %%
data_file = 'Resources/sim_500K_describe.csv'
data_df = pd.read_csv(data_file)
data_df
# Out:
#    Y_Htr Outlet Temp  Y_Top Tower Temp  Y_Reflux Temp  Y_Pump Around Temp  \
# 0         730.903065        258.180124     150.001516          182.404267
# 1           0.464812          0.818734       0.024857            0.537200
#
#    Y_127 to Storage Temp  Y_140 to Storage Temp  Y_152 to Storage Temp  \
# 0             208.583966             223.395656             200.000577
# 1               3.056118               2.480886               0.301989
#
#    Y_160 to Storage Temp  Y_VTB to Storage Temp  Y_127 Strip Lvl Pcnt  \
# 0             193.254962             234.138494             64.853419
# 1               2.926116               0.932248              0.303531
#
#    Y_140 Strip Lvl Pcnt  Y_152 Strip Lvl Pcnt  Y_160 Strip Lvl Pcnt  \
# 0             49.999955             50.004461             63.240108
# 1              0.006435              0.025454              1.270432
#
#    Y_Vacuum Charge Flow   Y_REFLUX  Y_PUMP AROUND  Y_Wash Flow  \
# ...

# %%
print(data_df.loc[0,"Y_Htr Outlet Temp"])
print(data_df.loc[1,"Y_Htr Outlet Temp"])
# Out:
# 730.9030652693532
# 0.4648122421874053

# %%
k = 250000 # number of simulations

s = np.random.uniform(data_df.loc[0,"Y_Htr Outlet Temp"] - data_df.loc[1,"Y_Htr Outlet Temp"], data_df.loc[0,"Y_Htr Outlet Temp"] + data_df.loc[1,"Y_Htr Outlet Temp"], k)
sim_250K_df = pd.DataFrame(s, columns = ['Y_Htr Outlet Temp']) 
  
# displaying random integers in data frame 
sim_250K_df.head()
# Out:
#    Y_Htr Outlet Temp
# 0         731.159144
# 1         730.770871
# 2         731.345709
# 3         730.621683
# 4         730.488707

# %%
sim_250K_df['Y_Top Tower Temp'] = np.random.uniform(data_df.loc[0, 'Y_Top Tower Temp'] - data_df.loc[1, 'Y_Top Tower Temp'], data_df.loc[0, 'Y_Top Tower Temp'] + data_df.loc[1, 'Y_Top Tower Temp'], k)
sim_250K_df['Y_Reflux Temp'] = np.random.uniform(data_df.loc[0, 'Y_Reflux Temp'] - data_df.loc[1, 'Y_Reflux Temp'], data_df.loc[0, 'Y_Reflux Temp'] + data_df.loc[1,'Y_Reflux Temp'], k)
sim_250K_df['Y_Pump Around Temp'] = np.random.uniform(data_df.loc[0, 'Y_Pump Around Temp'] - data_df.loc[1, 'Y_Pump Around Temp'], data_df.loc[0, 'Y_Pump Around Temp'] + data_df.loc[1, 'Y_Pump Around Temp'], k)
sim_250K_df['Y_127 to Storage Temp'] = np.random.uniform(data_df.loc[0, 'Y_127 to Storage Temp'] - data_df.loc[1, 'Y_127 to Storage Temp'], data_df.loc[0, 'Y_127 to Storage Temp'] + data_df.loc[1, 'Y_127 to Storage Temp'], k)
sim_250K_df['Y_140 to Storage Temp'] = np.random.uniform(data_df.loc[0, 'Y_140 to Storage Temp'] - data_df.loc[1, 'Y_140 to Storage Temp'], data_df.loc[0, 'Y_140 to Storage Temp'] + data_df.loc[1, 'Y_140 to Storage Temp'], k)
sim_250K_df['Y_152 to Storage Temp'] = np.random.uniform(data_df.loc[0, 'Y_152 to Storage Temp'] - data_df.loc[1, 'Y_152 to Storage Temp'], data_df.loc[0, 'Y_152 to Storage Temp'] + data_df.loc[1, 'Y_152 to Storage Temp'], k)
sim_250K_df['Y_160 to Storage Temp'] = np.random.uniform(data_df.loc[0, 'Y_160 to Storage Temp'] - data_df.loc[1, 'Y_160 to Storage Temp'], data_df.loc[0, 'Y_160 to Storage Temp'] + data_df.loc[1, 'Y_160 to Storage Temp'], k)
sim_250K_df['Y_VTB to Storage Temp'] = np.random.uniform(data_df.loc[0, 'Y_VTB to Storage Temp'] - data_df.loc[1, 'Y_VTB to Storage Temp'], data_df.loc[0, 'Y_VTB to Storage Temp'] + data_df.loc[1, 'Y_VTB to Storage Temp'], k)
sim_250K_df['Y_127 Strip Lvl Pcnt'] = np.random.uniform(data_df.loc[0, 'Y_127 Strip Lvl Pcnt'] - data_df.loc[1, 'Y_127 Strip Lvl Pcnt'], data_df.loc[0, 'Y_127 Strip Lvl Pcnt'] + data_df.loc[1, 'Y_127 Strip Lvl Pcnt'], k)
sim_250K_df['Y_140 Strip Lvl Pcnt'] = np.random.uniform(data_df.loc[0, 'Y_140 Strip Lvl Pcnt'] - data_df.loc[1, 'Y_140 Strip Lvl Pcnt'], data_df.loc[0, 'Y_140 Strip Lvl Pcnt'] + data_df.loc[1, 'Y_140 Strip Lvl Pcnt'], k)
sim_250K_df['Y_152 Strip Lvl Pcnt'] = np.random.uniform(data_df.loc[0, 'Y_152 Strip Lvl Pcnt'] - data_df.loc[1, 'Y_152 Strip Lvl Pcnt'], data_df.loc[0, 'Y_152 Strip Lvl Pcnt'] + data_df.loc[1, 'Y_152 Strip Lvl Pcnt'], k)
sim_250K_df['Y_160 Strip Lvl Pcnt'] = np.random.uniform(data_df.loc[0, 'Y_160 Strip Lvl Pcnt'] - data_df.loc[1, 'Y_160 Strip Lvl Pcnt'], data_df.loc[0, 'Y_160 Strip Lvl Pcnt'] + data_df.loc[1, 'Y_160 Strip Lvl Pcnt'], k)
sim_250K_df['Y_Vacuum Charge Flow'] = np.random.uniform(data_df.loc[0, 'Y_Vacuum Charge Flow'] - data_df.loc[1, 'Y_Vacuum Charge Flow'], data_df.loc[0, 'Y_Vacuum Charge Flow'] + data_df.loc[1, 'Y_Vacuum Charge Flow'], k)
sim_250K_df['Y_REFLUX'] = np.random.uniform(data_df.loc[0, 'Y_REFLUX'] - data_df.loc[1, 'Y_REFLUX'], data_df.loc[0, 'Y_REFLUX'] + data_df.loc[1, 'Y_REFLUX'], k)
sim_250K_df['Y_PUMP AROUND'] =  np.random.uniform(data_df.loc[0, 'Y_PUMP AROUND'] - data_df.loc[1, 'Y_PUMP AROUND'], data_df.loc[0, 'Y_PUMP AROUND'] + data_df.loc[1, 'Y_PUMP AROUND'], k)
sim_250K_df['Y_Wash Flow'] = np.random.uniform(data_df.loc[0, 'Y_Wash Flow'] - data_df.loc[1, 'Y_Wash Flow'], data_df.loc[0, 'Y_Wash Flow'] + data_df.loc[1, 'Y_Wash Flow'], k)
sim_250K_df['Y_127 to Storage Flow'] = np.random.uniform(data_df.loc[0, 'Y_127 to Storage Flow'] - data_df.loc[1, 'Y_127 to Storage Flow'], data_df.loc[0, 'Y_127 to Storage Flow'] + data_df.loc[1, 'Y_127 to Storage Flow'], k)
sim_250K_df['Y_140 to Storage Flow'] = np.random.uniform(data_df.loc[0, 'Y_140 to Storage Flow'] - data_df.loc[1, 'Y_140 to Storage Flow'], data_df.loc[0, 'Y_140 to Storage Flow'] + data_df.loc[1, 'Y_140 to Storage Flow'], k)
sim_250K_df['Y_152 to Storage Flow'] = np.random.uniform(data_df.loc[0, 'Y_152 to Storage Flow'] - data_df.loc[1, 'Y_152 to Storage Flow'], data_df.loc[0, 'Y_152 to Storage Flow'] + data_df.loc[1, 'Y_152 to Storage Flow'], k)
sim_250K_df['Y_160 to Storage Flow'] = np.random.uniform(data_df.loc[0, 'Y_160 to Storage Flow'] - data_df.loc[1, 'Y_160 to Storage Flow'], data_df.loc[0, 'Y_160 to Storage Flow'] + data_df.loc[1, 'Y_160 to Storage Flow'], k)
sim_250K_df['Y_8TH TUBE'] = np.random.uniform(data_df.loc[0, 'Y_8TH TUBE'] - data_df.loc[1, 'Y_8TH TUBE'], data_df.loc[0, 'Y_8TH TUBE'] + data_df.loc[1, 'Y_8TH TUBE'], k)
sim_250K_df['Y_Stripping Steam Tower Flow'] = np.random.uniform(data_df.loc[0, 'Y_Stripping Steam Tower Flow'] - data_df.loc[1, 'Y_Stripping Steam Tower Flow'], data_df.loc[0, 'Y_Stripping Steam Tower Flow'] + data_df.loc[1, 'Y_Stripping Steam Tower Flow'], k)
sim_250K_df['Y_127 Stripping Stream Flow'] = np.random.uniform(data_df.loc[0, 'Y_127 Stripping Stream Flow'] - data_df.loc[1, 'Y_127 Stripping Stream Flow'], data_df.loc[0, 'Y_127 Stripping Stream Flow'] + data_df.loc[1, 'Y_127 Stripping Stream Flow'], k)
sim_250K_df['Y_140 Stripping Stream Flow'] = np.random.uniform(data_df.loc[0, 'Y_140 Stripping Stream Flow'] - data_df.loc[1, 'Y_140 Stripping Stream Flow'], data_df.loc[0, 'Y_140 Stripping Stream Flow'] + data_df.loc[1, 'Y_140 Stripping Stream Flow'], k)
sim_250K_df['Y_152 Stripping Stream Flow'] = np.random.uniform(data_df.loc[0, 'Y_152 Stripping Stream Flow'] - data_df.loc[1, 'Y_152 Stripping Stream Flow'], data_df.loc[0, 'Y_152 Stripping Stream Flow'] + data_df.loc[1, 'Y_152 Stripping Stream Flow'], k)
sim_250K_df['Y_160 Stripping Stream Flow'] = np.random.uniform(data_df.loc[0, 'Y_160 Stripping Stream Flow'] - data_df.loc[1, 'Y_160 Stripping Stream Flow'], data_df.loc[0, 'Y_160 Stripping Stream Flow'] + data_df.loc[1, 'Y_160 Stripping Stream Flow'], k)

# %%
sim_250K_df
# Out:
#         Y_Htr Outlet Temp  Y_Top Tower Temp  Y_Reflux Temp  \
# 0              731.159144        258.042334     149.991252
# 1              730.770871        257.751418     149.977224
# 2              731.345709        258.898672     149.992772
# 3              730.621683        258.221134     149.978479
# 4              730.488707        257.702646     150.006241
# ...                   ...               ...            ...
# 249995         731.213336        257.569825     150.025166
# 249996         731.267579        258.541313     150.019027
# 249997         730.817277        258.633617     150.013371
# 249998         730.824637        258.178071     149.989920
# 249999         730.608593        258.207546     150.021003
#
#         Y_Pump Around Temp  Y_127 to Storage Temp  Y_140 to Storage Temp  \
# 0               182.024172             210.629701             221.780176
# 1               182.734029             211.564724             224.161706
# ...

# %%
sim_250K_df.to_csv('Resources/simulated_250K_data.csv',index=False)
