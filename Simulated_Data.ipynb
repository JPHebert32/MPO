# %%
# importing pandas and numpy libraries 
import numpy as np 
import pandas as pd

data_file = 'Resources/y_varaibles_describe.csv'
data_df = pd.read_csv(data_file)
#data_df.set_index("Unnamed: 0")
data_df
# Out:
#    Y_Htr Outlet Temp  Y_Top Tower Temp  Y_Reflux Temp  Y_Pump Around Temp  \
# 0         731.521581        256.819994     150.014709          183.524458
# 1           3.037210          5.860524       0.740130            2.732432
#
#    Y_127 to Storage Temp  Y_140 to Storage Temp  Y_152 to Storage Temp  \
# 0             213.231088             230.823621             199.995843
# 1              17.302324              19.185515               1.941896
#
#    Y_160 to Storage Temp  Y_VTB to Storage Temp  Y_127 Strip Lvl Pcnt  \
# 0             197.095999             234.005184             64.567353
# 1              16.314678               6.810913              2.784441
#
#    Y_140 Strip Lvl Pcnt  Y_152 Strip Lvl Pcnt  Y_160 Strip Lvl Pcnt  \
# 0             50.002494             50.019449             63.075334
# 1              1.003332              1.153270              7.040076
#
#    Y_Vacuum Charge Flow   Y_REFLUX  Y_PUMP AROUND  Y_Wash Flow  \
# ...

# %%
print(data_df.loc[0,"Y_Htr Outlet Temp"])
print(data_df.loc[1,"Y_Htr Outlet Temp"])
# Out:
# 731.5215808823558
# 3.0372102605707063

# %%
k = 100000    

s = np.random.uniform(data_df.loc[0,"Y_Htr Outlet Temp"] - data_df.loc[1,"Y_Htr Outlet Temp"], data_df.loc[0,"Y_Htr Outlet Temp"] + data_df.loc[1,"Y_Htr Outlet Temp"], k)
df = pd.DataFrame(s, columns = ['Y_Htr Outlet Temp']) 
  
# displaying random integers in data frame 
print(df)
# Out:
#        Y_Htr Outlet Temp
# 0             733.505696
# 1             734.056942
# 2             731.776533
# 3             731.587816
# 4             728.943309
# ...                  ...
# 99995         730.099026
# 99996         731.596682
# 99997         733.223238
# 99998         730.337748
# 99999         729.817746
#
# [100000 rows x 1 columns]

# %%
df['Y_Top Tower Temp'] = np.random.uniform(data_df.loc[0, 'Y_Top Tower Temp'] - data_df.loc[1, 'Y_Top Tower Temp'], data_df.loc[0, 'Y_Top Tower Temp'] + data_df.loc[1, 'Y_Top Tower Temp'], k)
df['Y_Reflux Temp'] = np.random.uniform(data_df.loc[0, 'Y_Reflux Temp'] - data_df.loc[1, 'Y_Reflux Temp'], data_df.loc[0, 'Y_Reflux Temp'] + data_df.loc[1,'Y_Reflux Temp'], k)
df['Y_Pump Around Temp'] = np.random.uniform(data_df.loc[0, 'Y_Pump Around Temp'] - data_df.loc[1, 'Y_Pump Around Temp'], data_df.loc[0, 'Y_Pump Around Temp'] + data_df.loc[1, 'Y_Pump Around Temp'], k)
df['Y_127 to Storage Temp'] = np.random.uniform(data_df.loc[0, 'Y_127 to Storage Temp'] - data_df.loc[1, 'Y_127 to Storage Temp'], data_df.loc[0, 'Y_127 to Storage Temp'] + data_df.loc[1, 'Y_127 to Storage Temp'], k)
df['Y_140 to Storage Temp'] = np.random.uniform(data_df.loc[0, 'Y_140 to Storage Temp'] - data_df.loc[1, 'Y_140 to Storage Temp'], data_df.loc[0, 'Y_140 to Storage Temp'] + data_df.loc[1, 'Y_140 to Storage Temp'], k)
df['Y_152 to Storage Temp'] = np.random.uniform(data_df.loc[0, 'Y_152 to Storage Temp'] - data_df.loc[1, 'Y_152 to Storage Temp'], data_df.loc[0, 'Y_152 to Storage Temp'] + data_df.loc[1, 'Y_152 to Storage Temp'], k)
df['Y_160 to Storage Temp'] = np.random.uniform(data_df.loc[0, 'Y_160 to Storage Temp'] - data_df.loc[1, 'Y_160 to Storage Temp'], data_df.loc[0, 'Y_160 to Storage Temp'] + data_df.loc[1, 'Y_160 to Storage Temp'], k)
df['Y_VTB to Storage Temp'] = np.random.uniform(data_df.loc[0, 'Y_VTB to Storage Temp'] - data_df.loc[1, 'Y_VTB to Storage Temp'], data_df.loc[0, 'Y_VTB to Storage Temp'] + data_df.loc[1, 'Y_VTB to Storage Temp'], k)
df['Y_127 Strip Lvl Pcnt'] = np.random.uniform(data_df.loc[0, 'Y_127 Strip Lvl Pcnt'] - data_df.loc[1, 'Y_127 Strip Lvl Pcnt'], data_df.loc[0, 'Y_127 Strip Lvl Pcnt'] + data_df.loc[1, 'Y_127 Strip Lvl Pcnt'], k)
df['Y_140 Strip Lvl Pcnt'] = np.random.uniform(data_df.loc[0, 'Y_140 Strip Lvl Pcnt'] - data_df.loc[1, 'Y_140 Strip Lvl Pcnt'], data_df.loc[0, 'Y_140 Strip Lvl Pcnt'] + data_df.loc[1, 'Y_140 Strip Lvl Pcnt'], k)
df['Y_152 Strip Lvl Pcnt'] = np.random.uniform(data_df.loc[0, 'Y_152 Strip Lvl Pcnt'] - data_df.loc[1, 'Y_152 Strip Lvl Pcnt'], data_df.loc[0, 'Y_152 Strip Lvl Pcnt'] + data_df.loc[1, 'Y_152 Strip Lvl Pcnt'], k)
df['Y_160 Strip Lvl Pcnt'] = np.random.uniform(data_df.loc[0, 'Y_160 Strip Lvl Pcnt'] - data_df.loc[1, 'Y_160 Strip Lvl Pcnt'], data_df.loc[0, 'Y_160 Strip Lvl Pcnt'] + data_df.loc[1, 'Y_160 Strip Lvl Pcnt'], k)
df['Y_Vacuum Charge Flow'] = np.random.uniform(data_df.loc[0, 'Y_Vacuum Charge Flow'] - data_df.loc[1, 'Y_Vacuum Charge Flow'], data_df.loc[0, 'Y_Vacuum Charge Flow'] + data_df.loc[1, 'Y_Vacuum Charge Flow'], k)
df['Y_REFLUX'] = np.random.uniform(data_df.loc[0, 'Y_REFLUX'] - data_df.loc[1, 'Y_REFLUX'], data_df.loc[0, 'Y_REFLUX'] + data_df.loc[1, 'Y_REFLUX'], k)
df['Y_PUMP AROUND'] =  np.random.uniform(data_df.loc[0, 'Y_PUMP AROUND'] - data_df.loc[1, 'Y_PUMP AROUND'], data_df.loc[0, 'Y_PUMP AROUND'] + data_df.loc[1, 'Y_PUMP AROUND'], k)
df['Y_Wash Flow'] = np.random.uniform(data_df.loc[0, 'Y_Wash Flow'] - data_df.loc[1, 'Y_Wash Flow'], data_df.loc[0, 'Y_Wash Flow'] + data_df.loc[1, 'Y_Wash Flow'], k)
df['Y_127 to Storage Flow'] = np.random.uniform(data_df.loc[0, 'Y_127 to Storage Flow'] - data_df.loc[1, 'Y_127 to Storage Flow'], data_df.loc[0, 'Y_127 to Storage Flow'] + data_df.loc[1, 'Y_127 to Storage Flow'], k)
df['Y_140 to Storage Flow'] = np.random.uniform(data_df.loc[0, 'Y_140 to Storage Flow'] - data_df.loc[1, 'Y_140 to Storage Flow'], data_df.loc[0, 'Y_140 to Storage Flow'] + data_df.loc[1, 'Y_140 to Storage Flow'], k)
df['Y_152 to Storage Flow'] = np.random.uniform(data_df.loc[0, 'Y_152 to Storage Flow'] - data_df.loc[1, 'Y_152 to Storage Flow'], data_df.loc[0, 'Y_152 to Storage Flow'] + data_df.loc[1, 'Y_152 to Storage Flow'], k)
df['Y_160 to Storage Flow'] = np.random.uniform(data_df.loc[0, 'Y_160 to Storage Flow'] - data_df.loc[1, 'Y_160 to Storage Flow'], data_df.loc[0, 'Y_160 to Storage Flow'] + data_df.loc[1, 'Y_160 to Storage Flow'], k)
df['Y_8TH TUBE'] = np.random.uniform(data_df.loc[0, 'Y_8TH TUBE'] - data_df.loc[1, 'Y_8TH TUBE'], data_df.loc[0, 'Y_8TH TUBE'] + data_df.loc[1, 'Y_8TH TUBE'], k)
df['Y_Stripping Steam Tower Flow'] = np.random.uniform(data_df.loc[0, 'Y_Stripping Steam Tower Flow'] - data_df.loc[1, 'Y_Stripping Steam Tower Flow'], data_df.loc[0, 'Y_Stripping Steam Tower Flow'] + data_df.loc[1, 'Y_Stripping Steam Tower Flow'], k)
df['Y_127 Stripping Stream Flow'] = np.random.uniform(data_df.loc[0, 'Y_127 Stripping Stream Flow'] - data_df.loc[1, 'Y_127 Stripping Stream Flow'], data_df.loc[0, 'Y_127 Stripping Stream Flow'] + data_df.loc[1, 'Y_127 Stripping Stream Flow'], k)
df['Y_140 Stripping Stream Flow'] = np.random.uniform(data_df.loc[0, 'Y_140 Stripping Stream Flow'] - data_df.loc[1, 'Y_140 Stripping Stream Flow'], data_df.loc[0, 'Y_140 Stripping Stream Flow'] + data_df.loc[1, 'Y_140 Stripping Stream Flow'], k)
df['Y_152 Stripping Stream Flow'] = np.random.uniform(data_df.loc[0, 'Y_152 Stripping Stream Flow'] - data_df.loc[1, 'Y_152 Stripping Stream Flow'], data_df.loc[0, 'Y_152 Stripping Stream Flow'] + data_df.loc[1, 'Y_152 Stripping Stream Flow'], k)
df['Y_160 Stripping Stream Flow'] = np.random.uniform(data_df.loc[0, 'Y_160 Stripping Stream Flow'] - data_df.loc[1, 'Y_160 Stripping Stream Flow'], data_df.loc[0, 'Y_160 Stripping Stream Flow'] + data_df.loc[1, 'Y_160 Stripping Stream Flow'], k)
df['B_Yield Variance VTB'] = np.random.uniform(data_df.loc[0, 'B_Yield Variance VTB'] - data_df.loc[1, 'B_Yield Variance VTB'], data_df.loc[0, 'B_Yield Variance VTB'] + data_df.loc[1, 'B_Yield Variance VTB'], k)

# %%
pd.set_option('display.max_columns', None)
df
# Out:
#        Y_Htr Outlet Temp  Y_Top Tower Temp  Y_Reflux Temp  Y_Pump Around Temp  \
# 0             733.505696        251.996277     149.711309          184.796844
# 1             734.056942        260.876350     150.649619          183.943337
# 2             731.776533        250.963469     149.852942          182.330891
# 3             731.587816        256.649225     149.407582          181.141292
# 4             728.943309        251.675894     149.794494          185.964693
# ...                  ...               ...            ...                 ...
# 99995         730.099026        258.959429     150.146657          183.657510
# 99996         731.596682        257.151644     149.774330          184.595227
# 99997         733.223238        252.547526     149.711752          185.266289
# 99998         730.337748        262.442181     150.046058          184.458994
# 99999         729.817746        262.411733     150.645229          184.690954
#
# ...

# %%
df.to_csv('Resources/simulated_data.csv',index=False)
