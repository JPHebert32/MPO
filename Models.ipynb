# %%
#Import non-sklearn packages
import pandas as pd
import numpy as np

#import sklearn auxillary packages
from sklearn.datasets import make_regression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.preprocessing import StandardScaler

#import sklearn regression models
from sklearn.linear_model import LinearRegression, Ridge, BayesianRidge
from sklearn.neighbors import KNeighborsRegressor

# %%
data_file = 'Resources/simulated_data.csv'
data_df = pd.read_csv(data_file)
data_df.head()
# Out:
#    Y_Htr Outlet Temp  Y_Top Tower Temp  Y_Reflux Temp  Y_Pump Around Temp  \
# 0         733.505696        251.996277     149.711309          184.796844
# 1         734.056942        260.876350     150.649619          183.943337
# 2         731.776533        250.963469     149.852942          182.330891
# 3         731.587816        256.649225     149.407582          181.141292
# 4         728.943309        251.675894     149.794494          185.964693
#
#    Y_127 to Storage Temp  Y_140 to Storage Temp  Y_152 to Storage Temp  \
# 0             214.618917             243.432008             200.169661
# 1             202.318524             244.962442             201.093201
# 2             211.677377             233.481366             199.437749
# 3             199.091260             225.867758             201.139666
# 4             211.564647             239.080687             201.682240
#
#    Y_160 to Storage Temp  Y_VTB to Storage Temp  Y_127 Strip Lvl Pcnt  ...  \
# 0             201.599644             237.127509             65.881661  ...
# 1             186.250686             233.116704             67.079162  ...
# 2             192.663932             228.507096             66.774371  ...
# 3             196.321674             235.756773             65.444175  ...
# 4             184.618487             239.062538             63.647259  ...
#
#    Y_140 to Storage Flow  Y_152 to Storage Flow  Y_160 to Storage Flow  \
# 0              53.554289              28.341741               3.338680
# 1              50.840219              27.377497               1.628091
# 2              54.213801              28.912807               1.978052
# 3              53.492792              26.378410               2.004399
# 4              51.718483              29.923208               1.318963
#
#    Y_8TH TUBE  Y_Stripping Steam Tower Flow  Y_127 Stripping Stream Flow  \
# 0  462.735619                    534.418762                   240.628069
# 1  453.294520                    601.425646                   239.125015
# 2  463.300371                    569.861618                   242.428012
# 3  458.109652                    594.649029                   239.742124
# 4  454.754899                    542.081175                   236.257937
#
#    Y_140 Stripping Stream Flow  Y_152 Stripping Stream Flow  \
# 0                    94.250033                   134.600869
# 1                    35.556507                   140.976499
# 2                    20.503091                   137.350798
# 3                     6.509737                   137.714298
# 4                    85.444647                   133.020179
#
#    Y_160 Stripping Stream Flow  B_Yield Variance VTB
# 0                    37.391479              0.072652
# 1                    13.462394              0.079970
# 2                    16.566327              0.082027
# 3                   -27.627538              0.071509
# 4                    25.337662              0.083926
#
# [5 rows x 28 columns]
